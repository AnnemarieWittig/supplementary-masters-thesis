# %% [markdown]
# # Grab Repository data

# %%
from dotenv import load_dotenv
from helper.general import split_by_date, generate_value_in_buckets, truncate_to_same_length, aggregate_by_date, get_repository_paths
from helper.significance import check_normality_of_buckets, use_normality_results_for_significance_independent
import logging
import pandas as pd
import ast
import os
import matplotlib.pyplot as plt

load_dotenv(override=True)
# Out:
# True

# %%
REPO_PATHS = os.getenv('STORAGE_DIRECTORIES')
repository_directories = ast.literal_eval(REPO_PATHS) if REPO_PATHS else []
INTRO_DATE = os.getenv('INTRO_DATE')
START_DATE = os.getenv('START_DATE')
END_DATE = os.getenv('END_DATE')
BUCKET_SIZE = int(os.getenv('BUCKET_SIZE'))
RESULTS_DIRECTORY = os.getenv("RESULTS_DIRECTORY")
storage_path = f'{RESULTS_DIRECTORY}/metric_calculation_{BUCKET_SIZE}/pull_requests_time_to_merge_per_{BUCKET_SIZE}_days.csv'

# Get only first-level subfolders in the repository directories
repositories = get_repository_paths(repository_directories)

print(repositories)
# Out:
# ['/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P3', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P9', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P2', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P8', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P1', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/k1bu0cscd4', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/5x4imrvk5b', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P7', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P5', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P14', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P6', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/non-participants', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/bznd2hh7ii', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/xd8qar3azx', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P4', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P13', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P12', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P10', '/Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/P11']

# %%
if INTRO_DATE == "":
    import json
    mapping_file = f"{repository_directories[0]}/mapping.json"
    # Check if the file exists
    if not os.path.exists(mapping_file):
        print(f"File not found: {mapping_file}. ")
    with open(mapping_file, 'r') as f:
        mapping = json.load(f)
    print(f"Using INTRO_DATE from mapping file: {INTRO_DATE}")

START_DATE = None
END_DATE = None
# Out:
# Using INTRO_DATE from mapping file:

# %% [markdown]
# # Generate PR Metrics per Repository

# %% [markdown]
# ## Time to merge Pull requests

# %%
def parse_duration(duration_str):
    try:
        days, hours, minutes, seconds = map(int, duration_str.split(":"))
        return pd.Timedelta(days=days, hours=hours, minutes=minutes, seconds=seconds)
    except:
        return pd.NaT  # handle invalid formats

# %%
pr_result = []
import numpy as np
for repository in repositories:
    if INTRO_DATE == "":
        person = repository.split('/')[-1]
        INTRO_DATE = mapping[person]['INTRO_DATE']
        START_DATE = mapping[person]['START_DATE']
        END_DATE = mapping[person]['END_DATE']
    pr_file = f"{repository}/pull_requests.csv"
    # Check if the file exists
    if not os.path.exists(pr_file) or os.stat(pr_file).st_size == 1:
        print(f"File not found or empty: {pr_file}. Skipping repository.")
        continue
    pr_df = pd.read_csv(pr_file)

    pr_df = truncate_to_same_length(pr_df, INTRO_DATE, 'created_at', 'defined', START_DATE, END_DATE)

    # pr_df = aggregate_by_date(pr_df, 'created_at', 'time_until_merged', 'sum')

    print(pr_df['created_at'].max())
    pr_df['time_until_merged_OG'] = pr_df['time_until_merged']
    # Apply to the column
    pr_df['time_until_merged'] = pr_df['time_until_merged'].apply(parse_duration)
    # Immediately convert it to float days
    pr_df['time_until_merged'] = pr_df['time_until_merged'].apply(
        lambda td: td.total_seconds() / (3600 * 24) if pd.notna(td) else np.nan
    )

    print(pr_df.head())

    
    pre_release, post_release = split_by_date(pr_df, INTRO_DATE, 'created_at')

    pre_release_buckets = generate_value_in_buckets(pre_release, 'created_at', 'time_until_merged', 'mean', BUCKET_SIZE, 'pre-')
    post_release_buckets = generate_value_in_buckets(post_release, 'created_at', 'time_until_merged', 'mean', BUCKET_SIZE, 'post-')

    release_buckets = pd.concat([pre_release_buckets, post_release_buckets], ignore_index=True)

    repo_name = repository.split('/')[-1]

    result_row = {'repository': repo_name}
    result_row.update(release_buckets.set_index('bucket')['time_until_merged'].to_dict())  # Use 'count' instead of 'value'
    
    pr_result.append(result_row)

# Create the DataFrame
pr_result_df = pd.DataFrame(pr_result)
# Out:
# 2025-02-14 14:14:51.338000+00:00
#    merge_id                                       sha      author  merged_by  \
# 1        55  74f90ec57250b58ee5ed5744a8311f7306fd8699  P3        NaN
# 3        54  a09f277fc1997d655fcf17c6a8b66f7f8622e9e1  P3        NaN
# 4        53  17c26445e26c92441ba9bb83c994945f45f08ff1  P3        NaN
# 5        52  b07cd20b684546bffb69839592b16cf82c0c334e  bznd2hh7ii        NaN
# 6        51  4e67a1cbc9e338e7e644bfb638aaa396f69cf94b  P3        NaN
#
#                     merged_at   state                       created_at  \
# 1  2025-03-13T14:31:03.886000  MERGED 2025-02-12 10:47:10.018000+00:00
# 3  2025-02-10T10:28:38.232000  MERGED 2025-02-07 14:16:10.162000+00:00
# 4  2025-02-05T12:28:04.347000  MERGED 2025-02-05 12:27:07.819000+00:00
# 5  2024-11-15T09:09:22.762000  MERGED 2024-11-14 15:05:57.118000+00:00
# 6  2024-09-16T11:15:20.810000  MERGED 2024-09-11 11:46:08.673000+00:00
#
#                    updated_at                   closed_at  \
# 1  2025-03-13T14:31:03.886000  2025-03-13T14:31:03.886000
# 3  2025-02-10T10:28:38.232000  2025-02-10T10:28:38.232000
# 4  2025-02-05T12:28:04.347000  2025-02-05T12:28:04.347000
# 5  2024-11-15T09:09:22.762000  2024-11-15T09:09:22.762000
# 6  2024-09-16T11:15:20.810000  2024-09-16T11:15:20.810000
#
#                                                title  \
# 1            Task/BANZKSTPO-589 migrate to openshift
# 3                    Adjust to new Jenkins structure
# 4                       add-artifact-copy-permission
# 5                          allow multiple host names
# 6  BANZKSTPO-393 create postgres Database for CVE...
#
#                                          description  \
# 1  * BANZKSTPO-589 create helm charts and change ...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#                                  requested_reviewers labels  \
# 1                                     ['bznd2hh7ii']     []
# 3  ['EX_c1fda2a6aeff3dc0c052e8656db4dcefc270f8ded...     []
# 4                                     ['P5']     []
# 5                                     ['P3']     []
# 6                                     ['bznd2hh7ii']     []
#
#                                            assignees time_until_closed  \
# 1                                     ['bznd2hh7ii']       29:03:43:53
# 3  ['EX_c1fda2a6aeff3dc0c052e8656db4dcefc270f8ded...       02:20:12:28
# 4                                     ['P5']       00:00:00:56
# 5                                     ['P3']       00:18:03:25
# 6                                     ['bznd2hh7ii']       04:23:29:12
#
#    time_until_merged time_until_merged_OG
# 1          29.155475          29:03:43:53
# 3           2.841991          02:20:12:28
# 4           0.000648          00:00:00:56
# 5           0.752373          00:18:03:25
# 6           4.978611          04:23:29:12
# 2025-02-14 12:01:28.639000+00:00
#    merge_id                                       sha      author  merged_by  \
# 0         2  12b15156c1c26148f1410c6c427aa701d24af8c4  P14        NaN
# 3       219  41d184042a5dd2af8483ee7f0206e53298cc18a7  P14        NaN
# 4       218  41d184042a5dd2af8483ee7f0206e53298cc18a7  P7        NaN
# 5       217  e556165f208b479e837aa6014946979d68c6ac5e  P9        NaN
# 6       216  493965e5e5ea68f49a762a06c506cce8ca79a687  P14        NaN
#
#                     merged_at   state                       created_at  \
# 0  2025-01-21T07:50:09.827000  MERGED 2025-01-20 08:41:22.334000+00:00
# 3  2025-02-10T13:25:43.251000  MERGED 2025-02-10 11:02:38.526000+00:00
# 4  2025-02-10T10:46:16.468000  MERGED 2025-02-10 09:48:41.077000+00:00
# 5  2025-01-07T11:22:01.115000  MERGED 2025-01-07 10:48:44.989000+00:00
# 6  2025-01-06T09:22:58.426000  MERGED 2025-01-03 13:34:08.406000+00:00
#
#                    updated_at                   closed_at  \
# 0  2025-01-21T07:50:09.827000  2025-01-21T07:50:09.827000
# 3  2025-02-10T13:25:43.251000  2025-02-10T13:25:43.251000
# 4  2025-02-10T10:46:16.468000  2025-02-10T10:46:16.468000
# 5  2025-01-07T11:22:01.115000  2025-01-07T11:22:01.115000
# 6  2025-01-06T09:22:58.426000  2025-01-06T09:22:58.426000
#
#                                          title description  \
# 0     [TREG-11607]: push to nexus upon git tag         NaN
# 3          [TREG-11859]: up parent pom version         NaN
# 4  [TREG-11979] Enable 'eintragung' for search         NaN
# 5                   TREG-11415 rollback spring         NaN
# 6          [TREG-11415]: up parent pom version         NaN
#
#   requested_reviewers labels       assignees time_until_closed  \
# 0      ['P9']     []  ['P9']       00:23:08:47
# 3      ['P9']     []  ['P9']       00:02:23:04
# 4      ['P9']     []  ['P9']       00:00:57:35
# 5      ['P7']     []  ['P7']       00:00:33:16
# 6      ['P9']     []  ['P9']       02:19:48:50
#
#    time_until_merged time_until_merged_OG
# 0           0.964433          00:23:08:47
# 3           0.099352          00:02:23:04
# 4           0.039988          00:00:57:35
# 5           0.023102          00:00:33:16
# 6           2.825579          02:19:48:50
# 2025-02-14 10:03:50.546000+00:00
#     merge_id                                       sha  \
# 16         6  5e5043aee36b1f25573bc32800eddd7b57beb077
# 25        41  15cccf1c7c0f20670d70f0a404b9a627aab97d8c
# 26        29  cf43752aeb204179d40e419e19127754c8821413
# 27        31  4b981c7f0b1d7492bab2811c685968092053de2d
# 51       265  fbcd7bdfcba6d26c2385f18871a3c8dae8569240
#
#                                                author  merged_by  \
# 16                                         P4        NaN
# 25  EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef3d...        NaN
# 26  EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef3d...        NaN
# 27                                         P2        NaN
# 51                                         P2        NaN
#
#                      merged_at   state                       created_at  \
# 16  2024-08-02T08:21:02.375000  MERGED 2024-08-02 08:09:49.270000+00:00
# 25  2024-07-26T13:31:52.765000  MERGED 2024-07-26 08:56:28.127000+00:00
# 26  2024-07-03T06:41:58.162000  MERGED 2024-06-25 08:17:33.597000+00:00
# 27  2024-07-02T11:19:01.439000  MERGED 2024-07-01 09:30:30.664000+00:00
# 51  2024-07-05T13:34:34.506000  MERGED 2024-07-04 07:43:03.256000+00:00
#
#                     updated_at                   closed_at  \
# 16  2024-08-02T08:21:02.375000  2024-08-02T08:21:02.375000
# 25  2024-07-26T13:31:52.765000  2024-07-26T13:31:52.765000
# 26  2024-07-03T06:41:58.162000  2024-07-03T06:41:58.162000
# 27  2024-07-02T11:19:01.439000  2024-07-02T11:19:01.439000
# 51  2024-07-05T13:34:34.506000  2024-07-05T13:34:34.506000
#
#                                                 title  \
# 16  BANZOT-141 - prune whole system instead of jus...
# 25                                    Task/BANZOT-140
# 26                         BANZOT-105 kafka resources
# 27                 BANZOT-119: add required matchType
# 51                 BANZOT-122: add grafana dashboards
#
#                                           description  \
# 16                                                NaN
# 25  * BANZOT-140 modul added\n* BANZOT-140 functio...
# 26                                                NaN
# 27                                                NaN
# 51                                                NaN
#
#                                   requested_reviewers labels  \
# 16                                     ['P2']     []
# 25                                     ['P2']     []
# 26                                     ['P2']     []
# 27  ['EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef...     []
# 51                                     ['5x4imrvk5b']     []
#
#                                             assignees time_until_closed  \
# 16                                     ['P2']       00:00:11:13
# 25                                     ['P2']       00:04:35:24
# 26                                     ['P2']       07:22:24:24
# 27  ['EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef...       01:01:48:30
# 51                                     ['5x4imrvk5b']       01:05:51:31
#
#     time_until_merged time_until_merged_OG
# 16           0.007789          00:00:11:13
# 25           0.191250          00:04:35:24
# 26           7.933611          07:22:24:24
# 27           1.075347          01:01:48:30
# 51           1.244109          01:05:51:31
# 2025-02-13 11:28:08.511000+00:00
#     merge_id                                       sha      author  merged_by  \
# 11       716  1ac7a1448c17df3008cbe8c94db68a26b52ababe  P8        NaN
# 12       719  cc309a749c4812d661e5e36ccfff0d3b096b79c2  P8        NaN
# 13       717  465bd7624735a8a801c6b18e92ac591b82b590ff  P8        NaN
# 14       715  7ea8a5c35a2260441f0e397a2687df8b1e18a7d0  P2        NaN
# 15       711  e0867f2f319214335676b1bbb70f835f1333fb99  P4        NaN
#
#                      merged_at   state                       created_at  \
# 11  2025-02-14T14:31:58.774000  MERGED 2025-02-12 13:16:15.027000+00:00
# 12  2025-02-14T13:50:30.473000  MERGED 2025-02-13 11:28:08.511000+00:00
# 13  2025-02-13T09:28:41.071000  MERGED 2025-02-13 08:16:49.670000+00:00
# 14  2025-02-12T10:02:23.904000  MERGED 2025-02-11 16:16:29.669000+00:00
# 15  2025-02-11T11:26:34.850000  MERGED 2025-02-10 14:04:37.810000+00:00
#
#                     updated_at                   closed_at  \
# 11  2025-02-14T14:31:58.774000  2025-02-14T14:31:58.774000
# 12  2025-02-14T13:50:30.473000  2025-02-14T13:50:30.473000
# 13  2025-02-13T09:28:41.071000  2025-02-13T09:28:41.071000
# 14  2025-02-12T10:02:23.904000  2025-02-12T10:02:23.904000
# 15  2025-02-11T11:26:34.850000  2025-02-11T11:26:34.850000
#
#                                                 title  \
# 11                      Task/IIS-2091 test deployment
# 12   [IIS-2101]: Improve handling of `ALLOW_ANY_USER`
# 13  [IIS-2099]: Check if file is being written to ...
# 14           [IIS-2085]: auth mock um Zuwem erweitern
# 15                   [IIS-2080] add /zuwem to ingress
#
#                                           description requested_reviewers  \
# 11                                                NaN      ['P12']
# 12                                                NaN      ['P2']
# 13  Unfortunately OS specific write locks are only...      ['P4']
# 14                                                NaN      ['P8']
# 15  - forward /zuwem to process-engine\n- move "pa...      ['P8']
#
#    labels       assignees time_until_closed  time_until_merged  \
# 11     []  ['P12']       02:01:15:43           2.052581
# 12     []  ['P2']       01:02:22:21           1.098854
# 13     []  ['P4']       00:01:11:51           0.049896
# 14     []  ['P8']       00:17:45:54           0.740208
# 15     []  ['P8']       00:21:21:57           0.890243
#
#    time_until_merged_OG
# 11          02:01:15:43
# 12          01:02:22:21
# 13          00:01:11:51
# 14          00:17:45:54
# 15          00:21:21:57
# 2025-02-14 14:44:01.819000+00:00
#      merge_id                                       sha      author  \
# 40        585  3aeb83fbb7863264f9780c9947e15fb0b2d3a9d2  5x4imrvk5b
# 41        584  ce349c2a2f750aa0cda56deea1338ad407ad161a  5x4imrvk5b
# 42        583  1b947321f383004c2c5ff74460254545414faae0  P1
# 43        581  551d4313c2f02f0272d3888221ebb039d7a76b45  P1
# 187       954  5806339c8df5447234832fbbeb0fe7248ad106fc  P1
#
#      merged_by                   merged_at   state  \
# 40         NaN  2024-07-02T14:27:55.375000  MERGED
# 41         NaN  2024-07-02T14:22:31.359000  MERGED
# 42         NaN  2024-07-02T14:21:45.099000  MERGED
# 43         NaN  2024-07-02T11:09:20.796000  MERGED
# 187        NaN  2025-02-18T09:12:24.565000  MERGED
#
#                           created_at                  updated_at  \
# 40  2024-07-02 13:35:57.741000+00:00  2024-07-02T14:27:55.375000
# 41  2024-07-02 12:14:12.004000+00:00  2024-07-02T14:22:31.359000
# 42  2024-07-02 11:54:42.979000+00:00  2024-07-02T14:21:45.099000
# 43  2024-07-01 18:33:41.249000+00:00  2024-07-02T11:09:20.796000
# 187 2025-02-14 14:44:01.819000+00:00  2025-02-18T09:12:24.565000
#
#                       closed_at  \
# 40   2024-07-02T14:27:55.375000
# 41   2024-07-02T14:22:31.359000
# 42   2024-07-02T14:21:45.099000
# 43   2024-07-02T11:09:20.796000
# 187  2025-02-18T09:12:24.565000
#
#                                                  title  \
# 40   [TREG-8783] Add locked_in_web check for order ...
# 41   [TREG-8648] Add locked company modal to order ...
# 42   Task/TREG-8646 Rechtseinheiten nicht anzeigen ...
# 43   Task/TREG-8644 Rechtseinheiten nicht anzeigen ...
# 187  [TREG-12098] define addOrRemoveErrors in abstr...
#
#                                            description  \
# 40                                                 NaN
# 41                                                 NaN
# 42   * [TREG-8646] hide locked RE in Reaktivierungs...
# 43   * [TREG-8644] get locked_in_web property by ex...
# 187                                                NaN
#
#               requested_reviewers labels                     assignees  \
# 40                 ['P1']     []                ['P1']
# 41   ['P9', 'P1']     []  ['P9', 'P1']
# 42   ['P9', '5x4imrvk5b']     []  ['P9', '5x4imrvk5b']
# 43                 ['P9']     []                ['P9']
# 187                ['P10']     []                ['P10']
#
#     time_until_closed  time_until_merged time_until_merged_OG
# 40        00:00:51:57           0.036076          00:00:51:57
# 41        00:02:08:19           0.089109          00:02:08:19
# 42        00:02:27:02           0.102106          00:02:27:02
# 43        00:16:35:39           0.691424          00:16:35:39
# 187       03:18:28:22           3.769699          03:18:28:22
# 2024-11-19 09:29:56.898000+00:00
#    merge_id                                       sha      author  merged_by  \
# 1       182  47e2a327fe8e835e58b74f3f7f4f6f7ddb29bbc0  k1bu0cscd4        NaN
# 2       180  97f8fdec4b4e96d1b7be28a1564cd734943476b0  k1bu0cscd4        NaN
# 3       163  3cd354dbf27c79fee1a180520f8c817f523d3a50  k1bu0cscd4        NaN
# 4       161  a329aa7c71409c934af62d0ba33133294371530b  k1bu0cscd4        NaN
# 5       156  280ccbca71147a18700b3a996b07927a52e85de9  k1bu0cscd4        NaN
#
#                     merged_at   state                       created_at  \
# 1  2024-11-26T08:41:06.511000  MERGED 2024-11-19 09:29:56.898000+00:00
# 2  2024-11-12T09:40:37.784000  MERGED 2024-11-12 07:35:46.682000+00:00
# 3  2024-10-11T10:55:17.793000  MERGED 2024-09-27 08:18:47.434000+00:00
# 4  2024-09-12T07:34:27.286000  MERGED 2024-09-12 07:33:16.881000+00:00
# 5  2024-08-29T08:07:46.147000  MERGED 2024-08-29 07:46:21.061000+00:00
#
#                    updated_at                   closed_at  \
# 1  2024-11-26T08:41:06.511000  2024-11-26T08:41:06.511000
# 2  2024-11-12T09:40:37.784000  2024-11-12T09:40:37.784000
# 3  2024-10-11T10:55:17.793000  2024-10-11T10:55:17.793000
# 4  2024-09-12T07:34:27.286000  2024-09-12T07:34:27.286000
# 5  2024-08-29T08:07:46.147000  2024-08-29T08:07:46.147000
#
#                                                title  \
# 1                   Task/IIS-1822 po review fix bugs
# 2  [IIS-1479] Add fact_check-icon to BWK-List sid...
# 3                   Task/IIS-1419 und IIS-1420 tests
# 4          Feature/IIS-950 Black White Conflict List
# 5        [IIS-999]: implement first BWK-List version
#
#                                          description  \
# 1  * [IIS-999]: implement first BWK-List version\...
# 2                                                NaN
# 3  * [IIS-1419]: Add tests\n* [IIS-1419 IIS-1420]...
# 4  * [IIS-999]: implement first BWK-List version\...
# 5                                                NaN
#
#             requested_reviewers labels                     assignees  \
# 1  ['P2', 'P12']     []  ['P2', 'P12']
# 2                ['P12']     []                ['P12']
# 3  ['P6', 'P8']     []  ['P6', 'P8']
# 4                ['P8']     []                ['P8']
# 5                ['P8']     []                ['P8']
#
#   time_until_closed  time_until_merged time_until_merged_OG
# 1       06:23:11:09           6.966076          06:23:11:09
# 2       00:02:04:51           0.086701          00:02:04:51
# 3       14:02:36:30          14.108681          14:02:36:30
# 4       00:00:01:10           0.000810          00:00:01:10
# 5       00:00:21:25           0.014873          00:00:21:25
# 2025-02-14 14:32:55.132000+00:00
#    merge_id                                       sha      author  merged_by  \
# 4       209  b37fc0148677dea0933d6bb617ad7aa466b471d8  5x4imrvk5b        NaN
# 5       207  e6e3a7498ca888f23d19a266aa542fc5b43e41c6  5x4imrvk5b        NaN
# 6       205  5a85c510d826c2b7949102c48800e7f6ade59c8c  5x4imrvk5b        NaN
# 7       201  a1527dfe9fcccce0e2a7291ca00b11dd101b5315  P9        NaN
# 8       200  a1527dfe9fcccce0e2a7291ca00b11dd101b5315  P14        NaN
#
#                     merged_at   state                       created_at  \
# 4  2024-10-21T13:27:33.531000  MERGED 2024-10-21 13:26:21.274000+00:00
# 5  2024-10-17T09:01:15.873000  MERGED 2024-10-17 07:45:30.050000+00:00
# 6  2024-10-10T12:27:14.419000  MERGED 2024-10-10 09:08:40.756000+00:00
# 7  2024-08-27T09:26:32.580000  MERGED 2024-08-27 09:22:18.171000+00:00
# 8  2024-08-26T10:36:33.978000  MERGED 2024-08-26 10:24:19.909000+00:00
#
#                    updated_at                   closed_at  \
# 4  2024-10-21T13:27:33.531000  2024-10-21T13:27:33.531000
# 5  2024-10-17T09:01:15.873000  2024-10-17T09:01:15.873000
# 6  2024-10-10T12:27:14.419000  2024-10-10T12:27:14.419000
# 7  2024-08-27T09:26:32.580000  2024-08-27T09:26:32.580000
# 8  2024-08-26T10:36:33.978000  2024-08-26T10:36:33.978000
#
#                                                title  \
# 4                 Story/TREG-7481 umhebungs pipeline
# 5  [TREG-10515] Move umhebung consumer to web pac...
# 6  [TREG-10347] Add logic for processing Umhebung...
# 7  Story/TREG-9344 deadletterqueues for all consu...
# 8  [TREG-9583]: add deadletterqueues to all consu...
#
#                                          description requested_reviewers  \
# 4  * [TREG-10347] Add logic for processing Umhebu...      ['P9']
# 5                                                NaN      ['P9']
# 6                                                NaN      ['P14']
# 7                                                NaN      ['5x4imrvk5b']
# 8                                                NaN      ['5x4imrvk5b']
#
#   labels       assignees time_until_closed  time_until_merged  \
# 4     []  ['P9']       00:00:01:12           0.000833
# 5     []  ['P9']       00:01:15:45           0.052604
# 6     []  ['P14']       00:03:18:33           0.137882
# 7     []  ['5x4imrvk5b']       00:00:04:14           0.002940
# 8     []  ['5x4imrvk5b']       00:00:12:14           0.008495
#
#   time_until_merged_OG
# 4          00:00:01:12
# 5          00:01:15:45
# 6          00:03:18:33
# 7          00:00:04:14
# 8          00:00:12:14
# 2025-02-14 12:29:51.274000+00:00
#     merge_id                                       sha  \
# 6        221  4a2ce03a2a7b6c9320a065fdbb183cabc19bd23c
# 7        220  4a2ce03a2a7b6c9320a065fdbb183cabc19bd23c
# 8        218  41d184042a5dd2af8483ee7f0206e53298cc18a7
# 9        217  e556165f208b479e837aa6014946979d68c6ac5e
# 10       208  5a85c510d826c2b7949102c48800e7f6ade59c8c
#
#                                                author  merged_by  \
# 6   EX_4fb9dc29743a6e2f079b88742a076919409233de4f2...        NaN
# 7   EX_4fb9dc29743a6e2f079b88742a076919409233de4f2...        NaN
# 8                                          P7        NaN
# 9                                          P9        NaN
# 10                                         P9        NaN
#
#                      merged_at   state                       created_at  \
# 6   2025-02-12T12:40:45.123000  MERGED 2025-02-12 11:46:29.660000+00:00
# 7   2025-02-12T11:45:58.460000  MERGED 2025-02-10 14:58:47.494000+00:00
# 8   2025-02-10T10:46:16.468000  MERGED 2025-02-10 09:48:41.077000+00:00
# 9   2025-01-07T11:22:01.115000  MERGED 2025-01-07 10:48:44.989000+00:00
# 10  2024-10-21T09:56:04.014000  MERGED 2024-10-21 07:15:51.600000+00:00
#
#                     updated_at                   closed_at  \
# 6   2025-02-12T12:40:45.123000  2025-02-12T12:40:45.123000
# 7   2025-02-12T11:45:58.460000  2025-02-12T11:45:58.460000
# 8   2025-02-10T10:46:16.468000  2025-02-10T10:46:16.468000
# 9   2025-01-07T11:22:01.115000  2025-01-07T11:22:01.115000
# 10  2024-10-21T09:56:04.014000  2024-10-21T09:56:04.014000
#
#                                                 title  \
# 6   Story/TREG-11844 remove ar registerart legal e...
# 7   [TREG-11906] delete ar registerart legal entities
# 8         [TREG-11979] Enable 'eintragung' for search
# 9                          TREG-11415 rollback spring
# 10               TREG-10494 disable concurrent builds
#
#                                           description requested_reviewers  \
# 6   * [TREG-11906] delete ar registerart legal ent...      ['P7']
# 7                                                 NaN      ['P7']
# 8                                                 NaN      ['P9']
# 9                                                 NaN      ['P7']
# 10                                                NaN      ['P7']
#
#    labels       assignees time_until_closed  time_until_merged  \
# 6      []  ['P7']       00:00:54:15           0.037674
# 7      []  ['P7']       01:20:47:10           1.866088
# 8      []  ['P9']       00:00:57:35           0.039988
# 9      []  ['P7']       00:00:33:16           0.023102
# 10     []  ['P7']       00:02:40:12           0.111250
#
#    time_until_merged_OG
# 6           00:00:54:15
# 7           01:20:47:10
# 8           00:00:57:35
# 9           00:00:33:16
# 10          00:02:40:12
# 2025-02-12 13:32:27.104000+00:00
#     merge_id                                       sha      author  merged_by  \
# 0         53  17c26445e26c92441ba9bb83c994945f45f08ff1  P3        NaN
# 6        952  6a34108d49b95e10d4fc9d67e978de9b29d5a368  P5        NaN
# 10       948  682850dd7a58d1634d9e3bd4312244d9a0e4f70d  P3        NaN
# 11       946  925393eea5655bbf011ed1f7195837652a059ba9  P3        NaN
# 12       947  20db4d06a55813ccd34668f8b7341da4c3071d71  P3        NaN
#
#                      merged_at   state                       created_at  \
# 0   2025-02-05T12:28:04.347000  MERGED 2025-02-05 12:27:07.819000+00:00
# 6   2025-02-28T12:25:19.535000  MERGED 2025-02-12 13:32:27.104000+00:00
# 10  2025-02-10T15:37:47.861000  MERGED 2025-02-05 14:31:57.295000+00:00
# 11  2025-02-05T15:23:01.574000  MERGED 2025-01-30 15:11:49.523000+00:00
# 12  2025-02-05T12:30:53.107000  MERGED 2025-02-05 12:05:04.700000+00:00
#
#                     updated_at                   closed_at  \
# 0   2025-02-05T12:28:04.347000  2025-02-05T12:28:04.347000
# 6   2025-02-28T12:25:19.535000  2025-02-28T12:25:19.535000
# 10  2025-02-10T15:37:47.861000  2025-02-10T15:37:47.861000
# 11  2025-02-05T15:23:01.574000  2025-02-05T15:23:01.574000
# 12  2025-02-05T12:30:53.107000  2025-02-05T12:30:53.107000
#
#                                                 title  \
# 0                        add-artifact-copy-permission
# 6   BANZKSTPO-741 implements MissingFlexopusAccoun...
# 10  add anwendergruppe change for personalnummer c...
# 11  Task/BANZKSTPO-904 add include all teams in ab...
# 12                       add artifact copy permission
#
#                                           description requested_reviewers  \
# 0                                                 NaN      ['P5']
# 6                                                 NaN      ['bznd2hh7ii']
# 10                                                NaN      ['P5']
# 11  * BANZKSTPO-904 add include all teams in abtei...      ['P5']
# 12                                                NaN      ['P5']
#
#    labels       assignees time_until_closed  time_until_merged  \
# 0      []  ['P5']       00:00:00:56           0.000648
# 6      []  ['bznd2hh7ii']       15:22:52:52          15.953380
# 10     []  ['P5']       05:01:05:50           5.045718
# 11     []  ['P5']       06:00:11:12           6.007778
# 12     []  ['P5']       00:00:25:48           0.017917
#
#    time_until_merged_OG
# 0           00:00:00:56
# 6           15:22:52:52
# 10          05:01:05:50
# 11          06:00:11:12
# 12          00:00:25:48
# 2025-02-14 12:29:51.274000+00:00
#    merge_id                                       sha  \
# 0         2  12b15156c1c26148f1410c6c427aa701d24af8c4
# 1         1  5d6d18f15cb024b89585b4afe8d3579827b27049
# 2       219  41d184042a5dd2af8483ee7f0206e53298cc18a7
# 3       216  493965e5e5ea68f49a762a06c506cce8ca79a687
# 4       211  4ecbadb043a3da5da205dec1fffbe4416f75876a
#
#                                               author  merged_by  \
# 0                                         P14        NaN
# 1                                         P14        NaN
# 2                                         P14        NaN
# 3                                         P14        NaN
# 4  EX_5cf738e2a341ac767d57850a2273137158e4df3dbea...        NaN
#
#                     merged_at   state                       created_at  \
# 0  2025-01-21T07:50:09.827000  MERGED 2025-01-20 08:41:22.334000+00:00
# 1  2024-10-25T08:27:54.966000  MERGED 2024-10-24 08:57:59.255000+00:00
# 2  2025-02-10T13:25:43.251000  MERGED 2025-02-10 11:02:38.526000+00:00
# 3  2025-01-06T09:22:58.426000  MERGED 2025-01-03 13:34:08.406000+00:00
# 4  2024-11-05T16:52:09.671000  MERGED 2024-11-04 08:32:59.661000+00:00
#
#                    updated_at                   closed_at  \
# 0  2025-01-21T07:50:09.827000  2025-01-21T07:50:09.827000
# 1  2024-10-25T08:27:54.966000  2024-10-25T08:27:54.966000
# 2  2025-02-10T13:25:43.251000  2025-02-10T13:25:43.251000
# 3  2025-01-06T09:22:58.426000  2025-01-06T09:22:58.426000
# 4  2024-11-05T16:52:09.671000  2024-11-05T16:52:09.671000
#
#                                                title description  \
# 0           [TREG-11607]: push to nexus upon git tag         NaN
# 1  [TREG-10548]: add rechtseinheiten backend open...         NaN
# 2                [TREG-11859]: up parent pom version         NaN
# 3                [TREG-11415]: up parent pom version         NaN
# 4  TREG-10025 TREG-10683: use problem-details fro...         NaN
#
#                                  requested_reviewers labels  \
# 0                                     ['P9']     []
# 1  ['EX_5cf738e2a341ac767d57850a2273137158e4df3db...     []
# 2                                     ['P9']     []
# 3                                     ['P9']     []
# 4                                     ['P14']     []
#
#                                            assignees time_until_closed  \
# 0                                     ['P9']       00:23:08:47
# 1  ['EX_5cf738e2a341ac767d57850a2273137158e4df3db...       00:23:29:55
# 2                                     ['P9']       00:02:23:04
# 3                                     ['P9']       02:19:48:50
# 4                                     ['P14']       01:08:19:10
#
#    time_until_merged time_until_merged_OG
# 0           0.964433          00:23:08:47
# 1           0.979109          00:23:29:55
# 2           0.099352          00:02:23:04
# 3           2.825579          02:19:48:50
# 4           1.346644          01:08:19:10
# 2025-02-13 11:45:20.645000+00:00
#      merge_id                                       sha      author  \
# 304       718  45fab7627c2ecb8a8212bb015d90d0e94f2e3050  P6
# 305       721  24de45fddf4093c626ea8999001add119a0976a9  P2
# 306       714  3165e7ffa14202872208fc3398d287f3ab2b9224  P6
# 307       712  b0496211db0c33521a8154e490780e54641ec021  P12
# 308       710  588ab451a0763974ff50a7c9860e2ce2da6ed053  P12
#
#      merged_by                   merged_at   state  \
# 304        NaN  2025-02-20T12:04:58.812000  MERGED
# 305        NaN  2025-02-18T08:52:19.230000  MERGED
# 306        NaN  2025-02-11T15:23:04.835000  MERGED
# 307        NaN  2025-02-11T13:28:42.607000  MERGED
# 308        NaN  2025-02-11T10:58:46.637000  MERGED
#
#                           created_at                  updated_at  \
# 304 2025-02-13 11:06:43.169000+00:00  2025-02-20T12:04:58.812000
# 305 2025-02-13 11:45:20.645000+00:00  2025-02-18T08:52:19.230000
# 306 2025-02-11 13:44:25.302000+00:00  2025-02-11T15:23:04.835000
# 307 2025-02-10 14:18:16.890000+00:00  2025-02-11T13:28:42.607000
# 308 2025-02-10 11:19:50.483000+00:00  2025-02-11T10:58:46.637000
#
#                       closed_at  \
# 304  2025-02-20T12:04:58.812000
# 305  2025-02-18T08:52:19.230000
# 306  2025-02-11T15:23:04.835000
# 307  2025-02-11T13:28:42.607000
# 308  2025-02-11T10:58:46.637000
#
#                                                  title  \
# 304  MERGE task/IIS-2052-tests INTO feature/IIS-202...
# 305                    [IIS-2082]: dto converter tests
# 306  MERGE task/IIS-2088-cleanup INTO Epic/Zuwendun...
# 307                 Task/IIS-2079 export zuwem entries
# 308  [IIS-2074] add zuwem export module and Controller
#
#                                            description  \
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
# 307  * [IIS-2074] add zuwem export module and Contr...
# 308                                                NaN
#
#               requested_reviewers labels                     assignees  \
# 304  ['P12', 'P2']     []  ['P12', 'P2']
# 305  ['P6', 'P12']     []  ['P6', 'P12']
# 306                ['P12']     []                ['P12']
# 307                ['P6']     []                ['P6']
# 308  ['P6', 'P8']     []  ['P6', 'P8']
#
#     time_until_closed  time_until_merged time_until_merged_OG
# 304       07:00:58:15           7.040451          07:00:58:15
# 305       04:21:06:58           4.879838          04:21:06:58
# 306       00:01:38:39           0.068507          00:01:38:39
# 307       00:23:10:25           0.965567          00:23:10:25
# 308       00:23:38:56           0.985370          00:23:38:56
# File not found or empty: /Users/annemariewittig/Master/repositoryanalysis/ITS/by_person/non-participants/pull_requests.csv. Skipping repository.
# 2025-02-14 14:14:51.338000+00:00
#     merge_id                                       sha  \
# 6        611  1fa52b3a2cb64143e74f5b328349953f09e0dfaa
# 93        55  74f90ec57250b58ee5ed5744a8311f7306fd8699
# 95        52  b07cd20b684546bffb69839592b16cf82c0c334e
# 96        51  4e67a1cbc9e338e7e644bfb638aaa396f69cf94b
# 97        50  ab198c45e28dbc775ff04cc8307cafa7038e718c
#
#                                                author  merged_by  \
# 6   EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef3d...        NaN
# 93                                         P3        NaN
# 95                                         bznd2hh7ii        NaN
# 96                                         P3        NaN
# 97                                         P3        NaN
#
#                      merged_at   state                       created_at  \
# 6   2024-08-13T11:01:06.754000  MERGED 2024-08-13 10:38:26.446000+00:00
# 93  2025-03-13T14:31:03.886000  MERGED 2025-02-12 10:47:10.018000+00:00
# 95  2024-11-15T09:09:22.762000  MERGED 2024-11-14 15:05:57.118000+00:00
# 96  2024-09-16T11:15:20.810000  MERGED 2024-09-11 11:46:08.673000+00:00
# 97  2024-06-26T13:29:33.307000  MERGED 2024-06-26 13:28:11.614000+00:00
#
#                     updated_at                   closed_at  \
# 6   2024-08-13T11:01:06.754000  2024-08-13T11:01:06.754000
# 93  2025-03-13T14:31:03.886000  2025-03-13T14:31:03.886000
# 95  2024-11-15T09:09:22.762000  2024-11-15T09:09:22.762000
# 96  2024-09-16T11:15:20.810000  2024-09-16T11:15:20.810000
# 97  2024-06-26T13:29:33.307000  2024-06-26T13:29:33.307000
#
#                                                 title  \
# 6            Task/TREG-9450 clean up clock timestamps
# 93            Task/BANZKSTPO-589 migrate to openshift
# 95                          allow multiple host names
# 96  BANZKSTPO-393 create postgres Database for CVE...
# 97        Fix nginx config to pass get-request values
#
#                                           description requested_reviewers  \
# 6   * TREG-9450 clean up clock timestamps added\n*...      ['bznd2hh7ii']
# 93  * BANZKSTPO-589 create helm charts and change ...      ['bznd2hh7ii']
# 95                                                NaN      ['P3']
# 96                                                NaN      ['bznd2hh7ii']
# 97                                                NaN      ['bznd2hh7ii']
#
#    labels       assignees time_until_closed  time_until_merged  \
# 6      []  ['bznd2hh7ii']       00:00:22:40           0.015741
# 93     []  ['bznd2hh7ii']       29:03:43:53          29.155475
# 95     []  ['P3']       00:18:03:25           0.752373
# 96     []  ['bznd2hh7ii']       04:23:29:12           4.978611
# 97     []  ['bznd2hh7ii']       00:00:01:21           0.000937
#
#    time_until_merged_OG
# 6           00:00:22:40
# 93          29:03:43:53
# 95          00:18:03:25
# 96          04:23:29:12
# 97          00:00:01:21
# 2025-02-14 12:54:55.875000+00:00
#     merge_id                                       sha      author  merged_by  \
# 24       654  41e9f59da496b06a3af90f6ec9046d7a7081d07f  P13        NaN
# 26       653  d806eee2a33fe75d0f21b27b09ce82d86e6363ec  P13        NaN
# 27       652  84afbfdc17321be658d251d1778d520084a82484  P13        NaN
# 28       648  84afbfdc17321be658d251d1778d520084a82484  P13        NaN
# 29       649  11b333c95e321aefea7f20d7c3fa20d1cb8709f3  xd8qar3azx        NaN
#
#                      merged_at   state                       created_at  \
# 24  2025-02-17T13:16:48.955000  MERGED 2025-02-14 12:54:55.875000+00:00
# 26  2025-02-14T07:35:18.788000  MERGED 2025-02-12 14:00:25.109000+00:00
# 27  2025-02-11T16:29:19.189000  MERGED 2025-02-11 14:36:03.043000+00:00
# 28  2025-02-11T14:25:15.077000  MERGED 2025-02-07 14:15:14.510000+00:00
# 29  2025-02-11T11:32:37.824000  MERGED 2025-02-10 14:49:09.532000+00:00
#
#                     updated_at                   closed_at  \
# 24  2025-02-17T13:16:48.955000  2025-02-17T13:16:48.955000
# 26  2025-02-14T07:35:18.788000  2025-02-14T07:35:18.788000
# 27  2025-02-11T16:29:19.189000  2025-02-11T16:29:19.189000
# 28  2025-02-11T14:25:15.077000  2025-02-11T14:25:15.077000
# 29  2025-02-11T11:32:37.824000  2025-02-11T11:32:37.824000
#
#                                                 title  \
# 24                        Bugfix/BANZZAU-840 reuse dm
# 26                            [BANZZAU-858] sonar fix
# 27  Story/BANZZAU-643 Unverknüpfte DocumentMetadat...
# 28  Task/BANZZAU-824 implementieren von 1 zu 1 req...
# 29         BANZZAU-844: Neue Schnittstelle /callbacks
#
#                                           description requested_reviewers  \
# 24  * [BANZZAU-840] write tests for new dm schema\...      ['xd8qar3azx']
# 26                                                NaN      ['xd8qar3azx']
# 27  * [BANZZAU-824] early cancel requestgroup if r...      ['xd8qar3azx']
# 28  * [BANZZAU-824] early cancel requestgroup if r...      ['xd8qar3azx']
# 29                                                NaN      ['P13']
#
#    labels       assignees time_until_closed  time_until_merged  \
# 24     []  ['xd8qar3azx']       03:00:21:53           3.015197
# 26     []  ['xd8qar3azx']       01:17:34:53           1.732558
# 27     []  ['xd8qar3azx']       00:01:53:16           0.078657
# 28     []  ['xd8qar3azx']       04:00:10:00           4.006944
# 29     []  ['P13']       00:20:43:28           0.863519
#
#    time_until_merged_OG
# 24          03:00:21:53
# 26          01:17:34:53
# 27          00:01:53:16
# 28          04:00:10:00
# 29          00:20:43:28
# 2025-02-14 10:03:50.546000+00:00
#    merge_id                                       sha  \
# 0        11  c3269839bab0d65039f0d116de96dc1a18e960f9
# 1        10  fe75bc974d5137d37173e993a7fd44dbda5a74db
# 2         9  649c62760709a7e0163360e1fef95a5b8f7047f9
# 3         7  058ada1c99f06aff55d0126c2cbbfaed1d4460f6
# 4         8  dec23537e5643f8335dac689c60c7a19e64dc110
#
#                                               author  merged_by  \
# 0                                         P4        NaN
# 1                                         P4        NaN
# 2                                         P4        NaN
# 3  EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef3d...        NaN
# 4                                         P4        NaN
#
#                     merged_at   state                       created_at  \
# 0  2024-10-23T14:17:13.640000  MERGED 2024-10-22 11:23:27.130000+00:00
# 1  2024-10-21T07:59:59.659000  MERGED 2024-10-21 07:33:29.709000+00:00
# 2  2024-09-10T07:31:37.233000  MERGED 2024-09-03 07:59:20.349000+00:00
# 3  2024-08-30T08:20:53.123000  MERGED 2024-08-27 06:26:55.053000+00:00
# 4  2024-08-29T07:55:00.007000  MERGED 2024-08-27 13:26:19.277000+00:00
#
#                    updated_at                   closed_at  \
# 0  2024-10-23T14:17:13.640000  2024-10-23T14:17:13.640000
# 1  2024-10-21T07:59:59.659000  2024-10-21T07:59:59.659000
# 2  2024-09-10T07:31:37.233000  2024-09-10T07:31:37.233000
# 3  2024-08-30T08:20:53.123000  2024-08-30T08:20:53.123000
# 4  2024-08-29T07:55:00.007000  2024-08-29T07:55:00.007000
#
#                                                title  \
# 0             BANZZAU-637 - enable docker tcp socket
# 1                              inc version to 10.7.0
# 2  BANZOT-143 - update registry cleanup documenta...
# 3                             BANZOT-146 cronjob 3,5
# 4  BANZOT-219 - enable any pkill arguments so tha...
#
#                 description  \
# 0  enable docker tcp socket
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                  requested_reviewers labels  \
# 0                                     ['bznd2hh7ii']     []
# 1                                     ['P9']     []
# 2  ['EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef...     []
# 3                                     ['P4']     []
# 4  ['EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef...     []
#
#                                            assignees time_until_closed  \
# 0                                     ['bznd2hh7ii']       01:02:53:46
# 1                                     ['P9']       00:00:26:29
# 2  ['EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef...       06:23:32:16
# 3                                     ['P4']       03:01:53:58
# 4  ['EX_5439cb2cf6f9d7b951a343d9978663b3c7e4348ef...       01:18:28:40
#
#    time_until_merged time_until_merged_OG
# 0           1.120671          01:02:53:46
# 1           0.018391          00:00:26:29
# 2           6.980741          06:23:32:16
# 3           3.079144          03:01:53:58
# 4           1.769907          01:18:28:40
# 2025-02-14 12:54:55.875000+00:00
#     merge_id                                       sha      author  merged_by  \
# 16       654  41e9f59da496b06a3af90f6ec9046d7a7081d07f  P13        NaN
# 18       653  d806eee2a33fe75d0f21b27b09ce82d86e6363ec  P13        NaN
# 19       652  84afbfdc17321be658d251d1778d520084a82484  P13        NaN
# 20       648  84afbfdc17321be658d251d1778d520084a82484  P13        NaN
# 21       649  11b333c95e321aefea7f20d7c3fa20d1cb8709f3  xd8qar3azx        NaN
#
#                      merged_at   state                       created_at  \
# 16  2025-02-17T13:16:48.955000  MERGED 2025-02-14 12:54:55.875000+00:00
# 18  2025-02-14T07:35:18.788000  MERGED 2025-02-12 14:00:25.109000+00:00
# 19  2025-02-11T16:29:19.189000  MERGED 2025-02-11 14:36:03.043000+00:00
# 20  2025-02-11T14:25:15.077000  MERGED 2025-02-07 14:15:14.510000+00:00
# 21  2025-02-11T11:32:37.824000  MERGED 2025-02-10 14:49:09.532000+00:00
#
#                     updated_at                   closed_at  \
# 16  2025-02-17T13:16:48.955000  2025-02-17T13:16:48.955000
# 18  2025-02-14T07:35:18.788000  2025-02-14T07:35:18.788000
# 19  2025-02-11T16:29:19.189000  2025-02-11T16:29:19.189000
# 20  2025-02-11T14:25:15.077000  2025-02-11T14:25:15.077000
# 21  2025-02-11T11:32:37.824000  2025-02-11T11:32:37.824000
#
#                                                 title  \
# 16                        Bugfix/BANZZAU-840 reuse dm
# 18                            [BANZZAU-858] sonar fix
# 19  Story/BANZZAU-643 Unverknüpfte DocumentMetadat...
# 20  Task/BANZZAU-824 implementieren von 1 zu 1 req...
# 21         BANZZAU-844: Neue Schnittstelle /callbacks
#
#                                           description requested_reviewers  \
# 16  * [BANZZAU-840] write tests for new dm schema\...      ['xd8qar3azx']
# 18                                                NaN      ['xd8qar3azx']
# 19  * [BANZZAU-824] early cancel requestgroup if r...      ['xd8qar3azx']
# 20  * [BANZZAU-824] early cancel requestgroup if r...      ['xd8qar3azx']
# 21                                                NaN      ['P13']
#
#    labels       assignees time_until_closed  time_until_merged  \
# 16     []  ['xd8qar3azx']       03:00:21:53           3.015197
# 18     []  ['xd8qar3azx']       01:17:34:53           1.732558
# 19     []  ['xd8qar3azx']       00:01:53:16           0.078657
# 20     []  ['xd8qar3azx']       04:00:10:00           4.006944
# 21     []  ['P13']       00:20:43:28           0.863519
#
#    time_until_merged_OG
# 16          03:00:21:53
# 18          01:17:34:53
# 19          00:01:53:16
# 20          04:00:10:00
# 21          00:20:43:28
# 2025-02-13 11:45:20.645000+00:00
#     merge_id                                       sha      author  merged_by  \
# 15       718  45fab7627c2ecb8a8212bb015d90d0e94f2e3050  P6        NaN
# 16       721  24de45fddf4093c626ea8999001add119a0976a9  P2        NaN
# 19       713  0a68172eaea8d8223b792ce21ad0101abd9c7554  P4        NaN
# 20       716  1ac7a1448c17df3008cbe8c94db68a26b52ababe  P8        NaN
# 21       720  0dfba87bac85aea1b4c3857aa6b0ad177e3a1cae  P12        NaN
#
#                      merged_at   state                       created_at  \
# 15  2025-02-20T12:04:58.812000  MERGED 2025-02-13 11:06:43.169000+00:00
# 16  2025-02-18T08:52:19.230000  MERGED 2025-02-13 11:45:20.645000+00:00
# 19  2025-02-17T10:53:55.697000  MERGED 2025-02-11 11:37:57.322000+00:00
# 20  2025-02-14T14:31:58.774000  MERGED 2025-02-12 13:16:15.027000+00:00
# 21  2025-02-13T14:31:02.833000  MERGED 2025-02-13 11:45:15.967000+00:00
#
#                     updated_at                   closed_at  \
# 15  2025-02-20T12:04:58.812000  2025-02-20T12:04:58.812000
# 16  2025-02-18T08:52:19.230000  2025-02-18T08:52:19.230000
# 19  2025-02-17T10:53:55.697000  2025-02-17T10:53:55.697000
# 20  2025-02-14T14:31:58.774000  2025-02-14T14:31:58.774000
# 21  2025-02-13T14:31:02.833000  2025-02-13T14:31:02.833000
#
#                                                 title  \
# 15  MERGE task/IIS-2052-tests INTO feature/IIS-202...
# 16                    [IIS-2082]: dto converter tests
# 19  Task/IIS-2086 App nicht herunterfahren nach im...
# 20                      Task/IIS-2091 test deployment
# 21                    [IIS-2102] adjust documentation
#
#                                           description  \
# 15                                                NaN
# 16                                                NaN
# 19  * [IIS-2086] never restart zuwem_excel_import\...
# 20                                                NaN
# 21                                                NaN
#
#              requested_reviewers labels                     assignees  \
# 15  ['P12', 'P2']     []  ['P12', 'P2']
# 16  ['P6', 'P12']     []  ['P6', 'P12']
# 19                ['P12']     []                ['P12']
# 20                ['P12']     []                ['P12']
# 21                ['P2']     []                ['P2']
#
#    time_until_closed  time_until_merged time_until_merged_OG
# 15       07:00:58:15           7.040451          07:00:58:15
# 16       04:21:06:58           4.879838          04:21:06:58
# 19       05:23:15:58           5.969421          05:23:15:58
# 20       02:01:15:43           2.052581          02:01:15:43
# 21       00:02:45:46           0.115116          00:02:45:46
# 2025-02-14 14:44:01.819000+00:00
#     merge_id                                       sha      author  merged_by  \
# 11       710  dc843b1a75ab2b1e3bb755e9753007ef5bc78349  P10        NaN
# 12       708  848d03eea607eda5a73674897715303b246de7a3  P10        NaN
# 13       709  e80129a3bce493da62656d785421e3cbdc3f45ae  P14        NaN
# 14       707  e80129a3bce493da62656d785421e3cbdc3f45ae  P10        NaN
# 15       705  647c0f2da381ce1fd17cd2b927d2dd44bd790c9b  P10        NaN
#
#                      merged_at   state                       created_at  \
# 11  2025-02-13T14:20:14.097000  MERGED 2025-02-13 14:17:04.558000+00:00
# 12  2025-02-13T14:15:33.700000  MERGED 2025-02-13 10:06:15.913000+00:00
# 13  2025-02-13T12:37:55.424000  MERGED 2025-02-13 11:20:49.487000+00:00
# 14  2025-02-12T15:53:57.384000  MERGED 2025-02-12 15:47:57.228000+00:00
# 15  2025-02-11T13:30:45.006000  MERGED 2025-02-04 12:42:54.004000+00:00
#
#                     updated_at                   closed_at  \
# 11  2025-02-13T14:20:14.097000  2025-02-13T14:20:14.097000
# 12  2025-02-13T14:15:33.700000  2025-02-13T14:15:33.700000
# 13  2025-02-13T12:37:55.424000  2025-02-13T12:37:55.424000
# 14  2025-02-12T15:53:57.384000  2025-02-12T15:53:57.384000
# 15  2025-02-11T13:30:45.006000  2025-02-11T13:30:45.006000
#
#                                                 title  \
# 11                   Story/TREG-11924 textanpassungen
# 12     [TREG-12022] Fix key in obligor text migration
# 13  [TREG-12043]: adjust number of kept builds in ...
# 14  [TREG-12021] Update texts for obligor type sel...
# 15                      Fix local setup for db errors
#
#                                           description requested_reviewers  \
# 11  * [TREG-12021] Update texts for obligor type s...      ['P11']
# 12                                                NaN      ['P11']
# 13                                                NaN      ['P10']
# 14                                                NaN      ['P11']
# 15                                                NaN      ['5x4imrvk5b']
#
#    labels       assignees time_until_closed  time_until_merged  \
# 11     []  ['P11']       00:00:03:09           0.002188
# 12     []  ['P11']       00:04:09:17           0.173113
# 13     []  ['P10']       00:01:17:05           0.053530
# 14     []  ['P11']       00:00:06:00           0.004167
# 15     []  ['5x4imrvk5b']       07:00:47:51           7.033229
#
#    time_until_merged_OG
# 11          00:00:03:09
# 12          00:04:09:17
# 13          00:01:17:05
# 14          00:00:06:00
# 15          07:00:47:51
# 2025-02-14 15:46:10.273000+00:00
#     merge_id                                       sha      author  merged_by  \
# 34       712  7d748664cc4341705f5dfb2cdaf146fff7cf9656  P9        NaN
# 35       711  7d748664cc4341705f5dfb2cdaf146fff7cf9656  P11        NaN
# 36       710  dc843b1a75ab2b1e3bb755e9753007ef5bc78349  P10        NaN
# 37       708  848d03eea607eda5a73674897715303b246de7a3  P10        NaN
# 38       707  e80129a3bce493da62656d785421e3cbdc3f45ae  P10        NaN
#
#                      merged_at   state                       created_at  \
# 34  2025-02-14T12:10:14.388000  MERGED 2025-02-14 12:01:28.639000+00:00
# 35  2025-02-14T11:42:56.082000  MERGED 2025-02-13 15:44:24.459000+00:00
# 36  2025-02-13T14:20:14.097000  MERGED 2025-02-13 14:17:04.558000+00:00
# 37  2025-02-13T14:15:33.700000  MERGED 2025-02-13 10:06:15.913000+00:00
# 38  2025-02-12T15:53:57.384000  MERGED 2025-02-12 15:47:57.228000+00:00
#
#                     updated_at                   closed_at  \
# 34  2025-02-14T12:10:14.388000  2025-02-14T12:10:14.388000
# 35  2025-02-14T11:42:56.082000  2025-02-14T11:42:56.082000
# 36  2025-02-13T14:20:14.097000  2025-02-13T14:20:14.097000
# 37  2025-02-13T14:15:33.700000  2025-02-13T14:15:33.700000
# 38  2025-02-12T15:53:57.384000  2025-02-12T15:53:57.384000
#
#                                                 title  \
# 34  Story/TREG-11783 Abschalten der alten Informat...
# 35                 [TREG-12018] remove downloads page
# 36                   Story/TREG-11924 textanpassungen
# 37     [TREG-12022] Fix key in obligor text migration
# 38  [TREG-12021] Update texts for obligor type sel...
#
#                                           description requested_reviewers  \
# 34                                                NaN      ['P11']
# 35                                                NaN      ['P9']
# 36  * [TREG-12021] Update texts for obligor type s...      ['P11']
# 37                                                NaN      ['P11']
# 38                                                NaN      ['P11']
#
#    labels       assignees time_until_closed  time_until_merged  \
# 34     []  ['P11']       00:00:08:45           0.006076
# 35     []  ['P9']       00:19:58:31           0.832303
# 36     []  ['P11']       00:00:03:09           0.002188
# 37     []  ['P11']       00:04:09:17           0.173113
# 38     []  ['P11']       00:00:06:00           0.004167
#
#    time_until_merged_OG
# 34          00:00:08:45
# 35          00:19:58:31
# 36          00:00:03:09
# 37          00:04:09:17
# 38          00:00:06:00
# /var/folders/19/fmw641dj3bnfy5qbgqrzmf100000gn/T/ipykernel_66633/1453186131.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   release_buckets = pd.concat([pre_release_buckets, post_release_buckets], ignore_index=True)

# %%
# Ensure the columns are in the correct order
def sort_buckets(df, prefix_one, prefix_two):
    order = ['repository']
    
    for prefix in [prefix_one, prefix_two]:
        counter = 0
        contained = True
        
        while contained:
            order.append(f'{prefix}{counter}')
            
            counter += 1
            if not f'{prefix}{counter}' in df:
                contained = False
        
    return order

columns_order = sort_buckets(pr_result_df, 'pre-', 'post-')
pr_result_df = pr_result_df[columns_order]

# %%
pr_result_df
# Out:
#     repository      pre-0     pre-1     pre-2     pre-3     pre-4      pre-5  \
# 0   P3   6.371463  2.642677  1.785363  3.090523  5.698543   2.954974
# 1   P9   0.669967  0.833621  1.079917  0.673713  1.734561   0.201310
# 2   P2   2.835417       NaN  2.985327  3.331736  8.231096   1.335963
# 3   P8   0.825510  1.046712  2.797458  2.630781  1.361000   1.381300
# 4   P1   1.576633  1.040199  0.640623  0.984130  0.708667   0.493763
# 5   k1bu0cscd4  40.022315       NaN  0.014873  0.000810       NaN  14.108681
# 6   5x4imrvk5b   0.831814  0.929464  1.412832  0.706611  1.579890   0.149293
# 7   P7   2.546797  0.439751  0.463102  0.334453  1.530061   0.150285
# 8   P5   0.838254  8.235598  4.440460       NaN  3.129076   2.528536
# 9   P14   3.120690  0.910568  0.386672  0.991007  1.200066   0.126852
# 10  P6   0.582901  1.455742  1.975286  0.718766  3.433927   1.294728
# 11  bznd2hh7ii   4.983465  1.742590  1.168104  3.979357  6.827420   4.577975
# 12  xd8qar3azx        NaN       NaN       NaN       NaN       NaN        NaN
# 13  P4   0.892539  2.002896  0.481902  2.823388  1.188252   0.891013
# 14  P13   0.455419  1.402816  1.844786  3.285427  3.624389   0.541306
# 15  P12   1.825862  1.471861  1.890734  1.104631  1.952269   0.734831
# 16  P10   1.887519  0.847550  0.691142  0.288116  0.718917   0.570950
# 17  P11   1.146290  1.677090  0.886791  1.084413  0.573655   0.099962
#
#        pre-6     pre-7     pre-8    post-0    post-1    post-2     post-3  \
# 0   1.598874  3.809641  3.154489  4.274836  6.251366  1.699060   8.861547
# 1   0.630355  3.937755  0.876212  1.340155  8.076593  1.536465   0.342594
# 2        NaN  0.684949       NaN  4.106005  3.214150  4.424606   2.530651
# 3   2.463537  1.991658  1.646767  2.204495  3.271091  1.131748   1.417918
# 4   0.922520  1.191407  0.593164  0.703897  1.704208  4.579775   0.988599
# 5        NaN       NaN       NaN  3.526389       NaN       NaN        NaN
# 6   1.221402  1.675669  1.462449  0.468557  2.820632  1.852130   0.345207
# 7   0.688458  0.712245       NaN  1.960239  0.726551  2.504429   0.734436
# 8        NaN       NaN       NaN  2.109464  3.021570  4.023573   2.048176
# 9   1.229447  1.624879  0.093123  1.906608  2.066819  2.155775   4.721755
# 10  7.904809  2.226259  8.534633  3.962880  1.429651  3.917847   1.969045
# 11  1.795007  3.184929  3.058438  6.873169  1.481730  2.300096  11.128533
# 12       NaN       NaN       NaN  1.554245       NaN  1.845521        NaN
# 13  2.554992  2.302393  2.424284  0.761389  2.102806  1.512622   1.369510
# 14  0.283995  2.747583  3.739243  0.718089  2.172725  1.564825   1.369510
# 15  2.083084  0.886982  0.924817  2.556648  1.992607  3.307654   4.645689
# 16  0.420808  0.521632  1.053424  0.856206  1.594058  1.041116   0.271033
# 17  1.010293  1.955951  0.538893  0.647965  0.886090  1.128166   0.875394
#
#        post-4    post-5    post-6    post-7     post-8
# 0    5.448346       NaN  8.348713  3.107306   4.140583
# 1    2.798989  2.384428  1.101015       NaN   1.015454
# 2    2.717086  2.997818  1.778710  3.382674   3.577341
# 3    1.932731       NaN  2.834709  1.907109   1.761932
# 4   28.108819  1.571726  0.842692  1.236919   1.634934
# 5         NaN       NaN       NaN       NaN        NaN
# 6   16.279516  3.285259  0.686367  0.834407   2.805036
# 7    1.042663       NaN  0.019609  0.490176   0.993927
# 8   14.143414       NaN  0.503432  2.552047   3.903092
# 9    5.041753  2.557886  2.007507  1.443302   0.569012
# 10   9.504525  3.883015  2.988372  1.428500   2.656386
# 11   4.379869       NaN  8.988183  4.991505  13.579371
# 12   1.764884  0.314946  0.487011  1.608804        NaN
# 13   0.900366  2.020741  0.936475  0.367848   2.108407
# 14   0.900366       NaN       NaN  0.174281   1.404605
# 15   1.917436  1.127188  2.733836  2.020910   1.956184
# 16   0.412055       NaN  0.629456  1.071672   1.527710
# 17   0.690035  2.412942  0.864749  0.875803   0.353111

# %%
# for col in pr_result_df.columns[1:]:  # Skip 'repository'
#     pr_result_df[col] = pd.to_timedelta(pr_result_df[col], errors='coerce')

# %%
import numpy as np
from scipy.stats import linregress

# Plotting the visualization as a grouped bar chart
plt.figure(figsize=(12, 6))

# Extract the date columns (x-axis labels)
date_columns = [col for col in pr_result_df.columns if col != 'repository']
colors = ["#653F6C", "#BFD1E5", "#BAB700", "#D8BFAA", "#439A86", "#808080", "#879970", "#896279"]
x = np.arange(len(date_columns))  # Numeric positions for the x-axis

# Bar width for grouped bars
bar_width = 0.15

# Loop through each repository and plot its bars
for i, repo in enumerate(pr_result_df['repository']):
    # Extract data for the current repository
    values = pr_result_df[pr_result_df['repository'] == repo].iloc[0, 1:].astype(float).fillna(0)
    # Adjust the x positions for this repository's bars
    plt.bar(x + i * bar_width, values.values, bar_width, label=repo, color=colors[i % len(colors)])
    
    # Add a regression line for the repository
    # Perform linear regression
    slope, intercept, _, _, _ = linregress(x, values.values)
    regression_line = slope * x + intercept
    plt.plot(x + i * bar_width, regression_line, color=colors[i % len(colors)], linestyle='--', label=f"_nolegend_")

# Dynamically find the largest 'pre-x' and 'post-0'
x_ticks = pr_result_df.columns[1:]  # Assuming these are the x-axis labels
pre_columns = [col for col in x_ticks if col.startswith('pre-')]
post_columns = [col for col in x_ticks if col.startswith('post-')]

if pre_columns and post_columns:
    largest_pre = max(pre_columns, key=lambda x: int(x.split('-')[1]))  # Find the largest 'pre-x'
    post_0 = 'post-0' if 'post-0' in post_columns else None  # Ensure 'post-0' exists

    if largest_pre and post_0:
        pre_index = list(x_ticks).index(largest_pre)
        post_0_index = list(x_ticks).index(post_0)
        midpoint = (pre_index + post_0_index) / 2
        plt.axvline(x=midpoint, color='red', linestyle='--', linewidth=2, label=INTRO_DATE)

# Set x-axis ticks and labels
plt.xticks(x + (len(pr_result_df['repository']) - 1) * bar_width / 2, date_columns, rotation=45)

# Add labels and title
plt.title('Repository Values Over Time with regression line (LOGARITHMIC SCALE)')
plt.xlabel('created_at')
plt.ylabel('Values')
plt.legend(title='Repository')
plt.tight_layout()
plt.yscale('log')
plt.show()

# %%
import numpy as np
from scipy.stats import linregress

tangent_data = []

# Plotting the visualization as a grouped bar chart
plt.figure(figsize=(12, 6))

# Extract the date columns (x-axis labels)
date_columns = [col for col in pr_result_df.columns if col != 'repository']
colors = ["#FF4500", "#FFA500", "#FF8C00", "#FFD700", "#FF6347", "#FF7F50", "#FFB347", "#FFCC99"]
colors = ["#653F6C", "#BFD1E5", "#BAB700", "#FFCC99", "#439A86", "#808080", "#879970", "#896279"]
x = np.arange(len(date_columns))  # Numeric positions for the x-axis

# Bar width for grouped bars
bar_width = 0.15

# Loop through each repository and plot its bars
for i, repo in enumerate(pr_result_df['repository']):
    # Extract data for the current repository
    values = pr_result_df[pr_result_df['repository'] == repo].iloc[0, 1:].astype(float).fillna(0)
    # Adjust the x positions for this repository's bars
    plt.bar(x + i * bar_width, values.values, bar_width, label=repo, color=colors[i % len(colors)])
    
    # Add a regression line for the repository
    # Perform linear regression
    m, b, _, _, _ = linregress(x, values.values)
    regression_line = m * x + b
    plt.plot(x + i * bar_width, regression_line, color=colors[i % len(colors)], linestyle='-', label=f"_nolegend_")

# Dynamically find the largest 'pre-x' and 'post-0'
x_ticks = pr_result_df.columns[1:]  # Assuming these are the x-axis labels
pre_columns = [col for col in x_ticks if col.startswith('pre-')]
post_columns = [col for col in x_ticks if col.startswith('post-')]

if pre_columns and post_columns:
    largest_pre = max(pre_columns, key=lambda x: int(x.split('-')[1]))
    post_0 = 'post-0' if 'post-0' in post_columns else None
    
    if largest_pre and post_0:
        pre_index = list(x_ticks).index(largest_pre)
        post_0_index = list(x_ticks).index(post_0)
        midpoint = (pre_index + post_0_index) / 2

        # Vertical red line at midpoint
        plt.axvline(x=midpoint + (len(pr_result_df['repository']) - 1) * bar_width / 2,
                    color='red', linestyle='--', linewidth=2, label="INTRO_DATE")

# Plot bars and regression lines
for i, repo in enumerate(pr_result_df['repository']):
    values = pr_result_df[pr_result_df['repository'] == repo].iloc[0, 1:].astype(float).fillna(0)

    offset_x = x + i * bar_width
    plt.bar(offset_x, values.values, bar_width, label="_nolegend_", color=colors[i % len(colors)])

    if pre_columns and post_columns and largest_pre and post_0:
        # Indices for regression segments
        pre_range = np.arange(0, post_0_index + 1)
        post_range = np.arange(post_0_index, len(values))

        # Extract values
        pre_values = values.values[pre_range]
        post_values = values.values[post_range]

        # Regression before midpoint
        m_pre, b_pre, *_ = linregress(pre_range, pre_values)
        reg_line_pre = m_pre * pre_range + b_pre
        plt.plot(offset_x[pre_range], reg_line_pre, linestyle='--', linewidth=1.5,
                color=colors[i % len(colors)], label="_nolegend_", alpha=0.5)

        # Regression after midpoint
        m_post, b_post, *_ = linregress(post_range, post_values)
        reg_line_post = m_post * post_range + b_post
        plt.plot(offset_x[post_range], reg_line_post, linestyle='--', linewidth=1.5,
                color=colors[i % len(colors)], label="_nolegend_", alpha=0.5)

        # Collect regression parameters
        tangent_data.append({
            'repository': repo,
            'm_pre': m_pre,
            'b_pre': b_pre,
            'm_post': m_post,
            'b_post': b_post
        })




# Set x-axis ticks and labels
plt.xticks(x + (len(pr_result_df['repository']) - 1) * bar_width / 2, date_columns, rotation=45)

# Add labels and title
plt.title('Repository Values Over Time with regression line (LOGARITHMIC SCALE)')
plt.xlabel('created_at')
plt.ylabel('Values')
plt.legend(title='Repository')
plt.tight_layout()
plt.yscale('log')
plt.show()

# %% [markdown]
# # Significancetest

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

print(pr_result_df.head())

# Columns for pre and after buckets
pre_columns = [col for col in pr_result_df.columns if col.startswith("pre-")]
after_columns = [col for col in pr_result_df.columns if col.startswith("post-")]

normality_results = check_normality_of_buckets(pr_result_df, pre_columns, after_columns)

# Display the results
print(normality_results)
# Out:
#    repository     pre-0     pre-1     pre-2     pre-3     pre-4     pre-5  \
# 0  P3  6.371463  2.642677  1.785363  3.090523  5.698543  2.954974
# 1  P9  0.669967  0.833621  1.079917  0.673713  1.734561  0.201310
# 2  P2  2.835417       NaN  2.985327  3.331736  8.231096  1.335963
# 3  P8  0.825510  1.046712  2.797458  2.630781  1.361000  1.381300
# 4  P1  1.576633  1.040199  0.640623  0.984130  0.708667  0.493763
#
#       pre-6     pre-7     pre-8    post-0    post-1    post-2    post-3  \
# 0  1.598874  3.809641  3.154489  4.274836  6.251366  1.699060  8.861547
# 1  0.630355  3.937755  0.876212  1.340155  8.076593  1.536465  0.342594
# 2       NaN  0.684949       NaN  4.106005  3.214150  4.424606  2.530651
# 3  2.463537  1.991658  1.646767  2.204495  3.271091  1.131748  1.417918
# 4  0.922520  1.191407  0.593164  0.703897  1.704208  4.579775  0.988599
#
#       post-4    post-5    post-6    post-7    post-8
# 0   5.448346       NaN  8.348713  3.107306  4.140583
# 1   2.798989  2.384428  1.101015       NaN  1.015454
# 2   2.717086  2.997818  1.778710  3.382674  3.577341
# 3   1.932731       NaN  2.834709  1.907109  1.761932
# 4  28.108819  1.571726  0.842692  1.236919  1.634934
#     repository  pre_p_value  after_p_value  pre_normal  after_normal
# 0   P3     0.204021       0.803079        True          True
# 1   P9     0.002005       0.003252       False         False
# 2   P2     0.115782       0.993684        True          True
# 3   P8     0.532181       0.717932        True          True
# 4   P1     0.591522       0.000004        True         False
# 5   k1bu0cscd4     0.179484            NaN        True         False
# 6   5x4imrvk5b     0.493439       0.000078        True         False
# 7   P7     0.028530       0.415053       False          True
# 8   P5     0.634290       0.001229        True         False
# 9   P14     0.153852       0.095089        True          True
# 10  P6     0.010607       0.007493       False         False
# 11  bznd2hh7ii     0.750817       0.775985        True          True
# 12  xd8qar3azx          NaN       0.048501       False         False
# 13  P4     0.253908       0.337689        True          True
# 14  P13     0.185812       0.963353        True          True
# 15  P12     0.181790       0.231053        True          True
# 16  P10     0.050288       0.670667        True          True
# 17  P11     0.898034       0.003431        True         False
# /Users/annemariewittig/Master/repo-analysis/metricScripts/helper/significance.py:24: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   after_stat, after_p = shapiro(after_values)
# /Users/annemariewittig/Master/repo-analysis/metricScripts/helper/significance.py:23: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   pre_stat, pre_p = shapiro(pre_values)

# %%
# significance_results_df = use_normality_results_for_significance_independent(normality_results, pr_result_df, pre_columns, after_columns)

# # Display the results
# print(significance_results_df)

from helper.significance import calculate_cliffs_delta_with_confidence
significance_results_df = calculate_cliffs_delta_with_confidence(pr_result_df, pre_columns, after_columns)

# Display the results
print(significance_results_df)
# Out:
#     repository      test_used  effect_size  ci_lower  ci_upper
# 0   P3  Cliff's Delta     0.419753 -0.049691  0.851852
# 1   P9  Cliff's Delta     0.419753 -0.086420  0.851852
# 2   P2  Cliff's Delta     0.172840 -0.271605  0.555864
# 3   P8  Cliff's Delta     0.222222 -0.283951  0.691358
# 4   P1  Cliff's Delta     0.604938  0.160494  0.950617
# 5   k1bu0cscd4  Cliff's Delta     0.000000 -0.074074  0.098765
# 6   5x4imrvk5b  Cliff's Delta     0.259259 -0.358025  0.802469
# 7   P7  Cliff's Delta     0.246914 -0.197840  0.716049
# 8   P5  Cliff's Delta    -0.074074 -0.444444  0.283951
# 9   P14  Cliff's Delta     0.679012  0.283951  1.000000
# 10  P6  Cliff's Delta     0.283951 -0.283951  0.777778
# 11  bznd2hh7ii  Cliff's Delta     0.444444 -0.049383  0.839815
# 12  xd8qar3azx  Cliff's Delta     0.000000  0.000000  0.000000
# 13  P4  Cliff's Delta    -0.259259 -0.728395  0.283951
# 14  P13  Cliff's Delta    -0.234568 -0.654321  0.197531
# 15  P12  Cliff's Delta     0.753086  0.333333  1.000000
# 16  P10  Cliff's Delta     0.172840 -0.370370  0.728395
# 17  P11  Cliff's Delta    -0.160494 -0.728395  0.432099

# %%
merged = pr_result_df.merge(significance_results_df, how='left')
merged.to_csv(storage_path)

merged
# Out:
#     repository      pre-0     pre-1     pre-2     pre-3     pre-4      pre-5  \
# 0   P3   6.371463  2.642677  1.785363  3.090523  5.698543   2.954974
# 1   P9   0.669967  0.833621  1.079917  0.673713  1.734561   0.201310
# 2   P2   2.835417       NaN  2.985327  3.331736  8.231096   1.335963
# 3   P8   0.825510  1.046712  2.797458  2.630781  1.361000   1.381300
# 4   P1   1.576633  1.040199  0.640623  0.984130  0.708667   0.493763
# 5   k1bu0cscd4  40.022315       NaN  0.014873  0.000810       NaN  14.108681
# 6   5x4imrvk5b   0.831814  0.929464  1.412832  0.706611  1.579890   0.149293
# 7   P7   2.546797  0.439751  0.463102  0.334453  1.530061   0.150285
# 8   P5   0.838254  8.235598  4.440460       NaN  3.129076   2.528536
# 9   P14   3.120690  0.910568  0.386672  0.991007  1.200066   0.126852
# 10  P6   0.582901  1.455742  1.975286  0.718766  3.433927   1.294728
# 11  bznd2hh7ii   4.983465  1.742590  1.168104  3.979357  6.827420   4.577975
# 12  xd8qar3azx        NaN       NaN       NaN       NaN       NaN        NaN
# 13  P4   0.892539  2.002896  0.481902  2.823388  1.188252   0.891013
# 14  P13   0.455419  1.402816  1.844786  3.285427  3.624389   0.541306
# 15  P12   1.825862  1.471861  1.890734  1.104631  1.952269   0.734831
# 16  P10   1.887519  0.847550  0.691142  0.288116  0.718917   0.570950
# 17  P11   1.146290  1.677090  0.886791  1.084413  0.573655   0.099962
#
#        pre-6     pre-7     pre-8  ...     post-3     post-4    post-5  \
# 0   1.598874  3.809641  3.154489  ...   8.861547   5.448346       NaN
# 1   0.630355  3.937755  0.876212  ...   0.342594   2.798989  2.384428
# 2        NaN  0.684949       NaN  ...   2.530651   2.717086  2.997818
# 3   2.463537  1.991658  1.646767  ...   1.417918   1.932731       NaN
# 4   0.922520  1.191407  0.593164  ...   0.988599  28.108819  1.571726
# 5        NaN       NaN       NaN  ...        NaN        NaN       NaN
# 6   1.221402  1.675669  1.462449  ...   0.345207  16.279516  3.285259
# 7   0.688458  0.712245       NaN  ...   0.734436   1.042663       NaN
# 8        NaN       NaN       NaN  ...   2.048176  14.143414       NaN
# 9   1.229447  1.624879  0.093123  ...   4.721755   5.041753  2.557886
# 10  7.904809  2.226259  8.534633  ...   1.969045   9.504525  3.883015
# 11  1.795007  3.184929  3.058438  ...  11.128533   4.379869       NaN
# 12       NaN       NaN       NaN  ...        NaN   1.764884  0.314946
# 13  2.554992  2.302393  2.424284  ...   1.369510   0.900366  2.020741
# 14  0.283995  2.747583  3.739243  ...   1.369510   0.900366       NaN
# 15  2.083084  0.886982  0.924817  ...   4.645689   1.917436  1.127188
# 16  0.420808  0.521632  1.053424  ...   0.271033   0.412055       NaN
# 17  1.010293  1.955951  0.538893  ...   0.875394   0.690035  2.412942
#
#       post-6    post-7     post-8      test_used  effect_size  ci_lower  \
# 0   8.348713  3.107306   4.140583  Cliff's Delta     0.419753 -0.049691
# 1   1.101015       NaN   1.015454  Cliff's Delta     0.419753 -0.086420
# 2   1.778710  3.382674   3.577341  Cliff's Delta     0.172840 -0.271605
# 3   2.834709  1.907109   1.761932  Cliff's Delta     0.222222 -0.283951
# 4   0.842692  1.236919   1.634934  Cliff's Delta     0.604938  0.160494
# 5        NaN       NaN        NaN  Cliff's Delta     0.000000 -0.074074
# 6   0.686367  0.834407   2.805036  Cliff's Delta     0.259259 -0.358025
# 7   0.019609  0.490176   0.993927  Cliff's Delta     0.246914 -0.197840
# 8   0.503432  2.552047   3.903092  Cliff's Delta    -0.074074 -0.444444
# 9   2.007507  1.443302   0.569012  Cliff's Delta     0.679012  0.283951
# 10  2.988372  1.428500   2.656386  Cliff's Delta     0.283951 -0.283951
# 11  8.988183  4.991505  13.579371  Cliff's Delta     0.444444 -0.049383
# 12  0.487011  1.608804        NaN  Cliff's Delta     0.000000  0.000000
# 13  0.936475  0.367848   2.108407  Cliff's Delta    -0.259259 -0.728395
# 14       NaN  0.174281   1.404605  Cliff's Delta    -0.234568 -0.654321
# 15  2.733836  2.020910   1.956184  Cliff's Delta     0.753086  0.333333
# 16  0.629456  1.071672   1.527710  Cliff's Delta     0.172840 -0.370370
# 17  0.864749  0.875803   0.353111  Cliff's Delta    -0.160494 -0.728395
#
#     ci_upper
# 0   0.851852
# 1   0.851852
# 2   0.555864
# 3   0.691358
# 4   0.950617
# 5   0.098765
# 6   0.802469
# 7   0.716049
# 8   0.283951
# 9   1.000000
# 10  0.777778
# 11  0.839815
# 12  0.000000
# 13  0.283951
# 14  0.197531
# 15  1.000000
# 16  0.728395
# 17  0.432099
#
# [18 rows x 23 columns]

# %%
merged = pr_result_df.merge(significance_results_df, how='left')
merged.to_csv(storage_path)

merged
# Out:
#     repository      pre-0     pre-1     pre-2     pre-3     pre-4      pre-5  \
# 0   P3   6.371463  2.642677  1.785363  3.090523  5.698543   2.954974
# 1   P9   0.669967  0.833621  1.079917  0.673713  1.734561   0.201310
# 2   P2   2.835417       NaN  2.985327  3.331736  8.231096   1.335963
# 3   P8   0.825510  1.046712  2.797458  2.630781  1.361000   1.381300
# 4   P1   1.576633  1.040199  0.640623  0.984130  0.708667   0.493763
# 5   k1bu0cscd4  40.022315       NaN  0.014873  0.000810       NaN  14.108681
# 6   5x4imrvk5b   0.831814  0.929464  1.412832  0.706611  1.579890   0.149293
# 7   P7   2.546797  0.439751  0.463102  0.334453  1.530061   0.150285
# 8   P5   0.838254  8.235598  4.440460       NaN  3.129076   2.528536
# 9   P14   3.120690  0.910568  0.386672  0.991007  1.200066   0.126852
# 10  P6   0.582901  1.455742  1.975286  0.718766  3.433927   1.294728
# 11  bznd2hh7ii   4.983465  1.742590  1.168104  3.979357  6.827420   4.577975
# 12  xd8qar3azx        NaN       NaN       NaN       NaN       NaN        NaN
# 13  P4   0.892539  2.002896  0.481902  2.823388  1.188252   0.891013
# 14  P13   0.455419  1.402816  1.844786  3.285427  3.624389   0.541306
# 15  P12   1.825862  1.471861  1.890734  1.104631  1.952269   0.734831
# 16  P10   1.887519  0.847550  0.691142  0.288116  0.718917   0.570950
# 17  P11   1.146290  1.677090  0.886791  1.084413  0.573655   0.099962
#
#        pre-6     pre-7     pre-8  ...     post-3     post-4    post-5  \
# 0   1.598874  3.809641  3.154489  ...   8.861547   5.448346       NaN
# 1   0.630355  3.937755  0.876212  ...   0.342594   2.798989  2.384428
# 2        NaN  0.684949       NaN  ...   2.530651   2.717086  2.997818
# 3   2.463537  1.991658  1.646767  ...   1.417918   1.932731       NaN
# 4   0.922520  1.191407  0.593164  ...   0.988599  28.108819  1.571726
# 5        NaN       NaN       NaN  ...        NaN        NaN       NaN
# 6   1.221402  1.675669  1.462449  ...   0.345207  16.279516  3.285259
# 7   0.688458  0.712245       NaN  ...   0.734436   1.042663       NaN
# 8        NaN       NaN       NaN  ...   2.048176  14.143414       NaN
# 9   1.229447  1.624879  0.093123  ...   4.721755   5.041753  2.557886
# 10  7.904809  2.226259  8.534633  ...   1.969045   9.504525  3.883015
# 11  1.795007  3.184929  3.058438  ...  11.128533   4.379869       NaN
# 12       NaN       NaN       NaN  ...        NaN   1.764884  0.314946
# 13  2.554992  2.302393  2.424284  ...   1.369510   0.900366  2.020741
# 14  0.283995  2.747583  3.739243  ...   1.369510   0.900366       NaN
# 15  2.083084  0.886982  0.924817  ...   4.645689   1.917436  1.127188
# 16  0.420808  0.521632  1.053424  ...   0.271033   0.412055       NaN
# 17  1.010293  1.955951  0.538893  ...   0.875394   0.690035  2.412942
#
#       post-6    post-7     post-8      test_used  effect_size  ci_lower  \
# 0   8.348713  3.107306   4.140583  Cliff's Delta     0.419753 -0.049691
# 1   1.101015       NaN   1.015454  Cliff's Delta     0.419753 -0.086420
# 2   1.778710  3.382674   3.577341  Cliff's Delta     0.172840 -0.271605
# 3   2.834709  1.907109   1.761932  Cliff's Delta     0.222222 -0.283951
# 4   0.842692  1.236919   1.634934  Cliff's Delta     0.604938  0.160494
# 5        NaN       NaN        NaN  Cliff's Delta     0.000000 -0.074074
# 6   0.686367  0.834407   2.805036  Cliff's Delta     0.259259 -0.358025
# 7   0.019609  0.490176   0.993927  Cliff's Delta     0.246914 -0.197840
# 8   0.503432  2.552047   3.903092  Cliff's Delta    -0.074074 -0.444444
# 9   2.007507  1.443302   0.569012  Cliff's Delta     0.679012  0.283951
# 10  2.988372  1.428500   2.656386  Cliff's Delta     0.283951 -0.283951
# 11  8.988183  4.991505  13.579371  Cliff's Delta     0.444444 -0.049383
# 12  0.487011  1.608804        NaN  Cliff's Delta     0.000000  0.000000
# 13  0.936475  0.367848   2.108407  Cliff's Delta    -0.259259 -0.728395
# 14       NaN  0.174281   1.404605  Cliff's Delta    -0.234568 -0.654321
# 15  2.733836  2.020910   1.956184  Cliff's Delta     0.753086  0.333333
# 16  0.629456  1.071672   1.527710  Cliff's Delta     0.172840 -0.370370
# 17  0.864749  0.875803   0.353111  Cliff's Delta    -0.160494 -0.728395
#
#     ci_upper
# 0   0.851852
# 1   0.851852
# 2   0.555864
# 3   0.691358
# 4   0.950617
# 5   0.098765
# 6   0.802469
# 7   0.716049
# 8   0.283951
# 9   1.000000
# 10  0.777778
# 11  0.839815
# 12  0.000000
# 13  0.283951
# 14  0.197531
# 15  1.000000
# 16  0.728395
# 17  0.432099
#
# [18 rows x 23 columns]

# %% [markdown]
# # Interpretation
# - react-native: huge effect; significantly less time to close after introducing the AI tool
# - vue: no significant effect
